# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_salience_moses_cl_clearsmi = pd.read_csv("../reports/data/moses_ClearSMILES_CL/5/pair_coherence_data_threshold1_sample_length7707.csv")
data_salience_moses_cl_cansmi = pd.read_csv("../reports/data/moses_canonical_CL/5/pair_coherence_data_threshold1_sample_length9942.csv")

# %%
data_salience_moses_cl_clearsmi
# Out:
#        Unnamed: 0  position of first of a pair  position of second of a pair  \
# 0               0                            7                             9
# 1               1                           15                            18
# 2               2                           19                            22
# 3               3                           28                            30
# 4               4                           10                            12
# ...           ...                          ...                           ...
# 27686       27686                            4                             7
# 27687       27687                           16                            20
# 27688       27688                           23                            26
# 27689       27689                           30                            33
# 27690       27690                           42                            44
#
# ...

# %%
data_salience_moses_cl_cansmi
# Out:
#        Unnamed: 0  position of first of a pair  position of second of a pair  \
# 0               0                            5                             8
# 1               1                           12                            15
# 2               2                           13                            15
# 3               3                           25                            27
# 4               4                            4                             6
# ...           ...                          ...                           ...
# 35171       35171                           34                            43
# 35172       35172                            3                             6
# 35173       35173                           13                            28
# 35174       35174                            5                             8
# 35175       35175                            3                            20
#
# ...

# %%
fig, ax = plt.subplots()

# %%
 fig, ax = plt.subplots()

    saliency_data = pd.DataFrame()
    saliency_data["vocabulary"] = vocabulary
    saliency_data["counting"] = counting
    dir_for_data = args.output_dir+"/histo_saliency_threshold"+str(args.threshold)+"_sample_length"+str(len(dataset))
    saliency_data.to_csv(dir_for_data+".csv")

    vocabulary = ["" if counting[k]<100 else vocabulary[k] for k in range(len(vocabulary))]
    ax.bar(vocabulary,counting, alpha=0.6, label=args.model)
    ax.set_ylabel('Number per bar')
    ax.set_xlabel('Tokens')
    ax.set_title('Density of tokens count according to the saliency - threshold of '+str(args.threshold))
    ax.legend()
    ax.grid()
    plt.savefig(dir_for_data+".png")

# %%
len("CC(C(=O)N1CCCC1)N1CCN(C(=O)c2cnccn2)CC1")
# Out:
# 39

# %%
moses_cl_clearsmi = pd.read_csv("../data/generated/moses_ClearSMILES_CL_5_1.csv")
moses_cl_clearsm2 = pd.read_csv("../data/generated/moses_ClearSMILES_CL_5_2.csv")
moses_cl_clearsm3 = pd.read_csv("../data/generated/moses_ClearSMILES_CL_5_3.csv")

moses_cl_clearsm4 = pd.DataFrame()
moses_cl_clearsm4["SMILES"] = moses_cl_clearsmi["SMILES"].tolist() + moses_cl_clearsm2["SMILES"].tolist() + moses_cl_clearsm3["SMILES"].tolist()

# %%
moses_cl_clearsm4.to_csv("../data/generated/30000samples_ClearSMILES_cl_5.csv")

# %%
sooo = pd.read_csv("../reports/data/BENCHMARK/BENCHMARK_ClearSMILES_moses_CL_6.csv")

# %%
sooo.describe()
# Out:
#            valid  unique@1000  unique@10000   FCD/Test   SNN/Test  Frag/Test  \
# count  30.000000    30.000000     30.000000  30.000000  30.000000  30.000000
# mean    0.446967     0.999733      0.999076   1.323430   0.627655   0.992128
# std     0.005559     0.000521      0.000501   0.053630   0.001788   0.000812
# min     0.435300     0.998000      0.997359   1.224230   0.624480   0.990425
# 25%     0.443500     1.000000      0.999096   1.278213   0.626437   0.991591
# 50%     0.447050     1.000000      0.999118   1.332335   0.627630   0.992210
# 75%     0.450125     1.000000      0.999326   1.364357   0.628442   0.992627
# max     0.459700     1.000000      1.000000   1.443457   0.630939   0.993385
#
#        Scaf/Test  FCD/TestSF  SNN/TestSF  Frag/TestSF  Scaf/TestSF     IntDiv  \
# count  30.000000   30.000000   30.000000    30.000000    30.000000  30.000000
# mean    0.793724    2.088600    0.574552     0.988421     0.073486   0.852929
# ...
