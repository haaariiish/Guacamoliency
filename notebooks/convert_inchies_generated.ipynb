# %%
import pandas as pd
import rdkit
from rdkit import Chem

part_0 = pd.read_parquet('../data/raw/inchie_logic_data/part-0.parquet')
part_0
# Out:
#                                                     block begin_tag end_tag  \
# 0       F-C1-C(=C-C=C(-C=1-F)-S(=O)(=O)-N-C1=C-C(-F)=C...    no_tag  no_tag
# 1                                    F-C1=C-C=C(-F)-C=C-1    no_tag     L16
# 2                                                       N        L5      L5
# 3                                               S(=O)(=O)  L12b_L12    L12b
# 4                              C1-C(-F)=C(-F)-C(=C-C=1)-F       L16  no_tag
# ...                                                   ...       ...     ...
# 257843                  C-C1-C2-C(=O)-N(-C)-C=N-C=2-S-C=1    no_tag     L14
# 257844                    O-C1=C-C=C-C2-C-1=N-C(=C-C=2)-C    no_tag     L7a
# 257845                        C-C1=C-N=C2-N-1-C=C(-C=C-2)       L7b     L16
# 257846                  C1(-C)-C-C2=C-C=C-C=C-2-C(-O-1)=O  L13_L14b  no_tag
# 257847                         C1-N(-N)-C(=O)-C(=N-N=1)-C       L14  no_tag
#
# ...

# %%
data_generated = pd.read_csv('../data/generated/moses_canonical_INCHIES_1.csv')
# Out:
#                                                  SMILES
# 0     WYURNTSHIVDZCO-UHFFFAOYSA-NVNWKTOKETHGBQD-UHFF...
# 1     UHOVQNZJYSORNB-UHFFFAOYSA-NVNWKTOKETHGBQD-UHFF...
# 2     PYLWMHQQBFSUBP-UHFFFAOYSA-NOTMSDBZUPAUEDD-UHFF...
# 3     IKHGUXGNUITLKF-UHFFFAOYSA-NQGZKDVFQNNGYKY-UHFF...
# 4     OKKJLVBELUTLKV-UHFFFAOYSA-NOTMSDBZUPAUEDD-UHFF...
# ...                                                 ...
# 9995  YTPLMLYBLZKORZ-UHFFFAOYSA-NVNWKTOKETHGBQD-UHFF...
# 9996  ATUOYWHBWRKTHZ-UHFFFAOYSA-NJJWLVOIRVHMVIS-UHFF...
# 9997  JUJWROOIHBZHMG-UHFFFAOYSA-NVNWKTOKETHGBQD-UHFF...
# 9998  UHOVQNZJYSORNB-UHFFFAOYSA-NKJUGUADJHNHALS-UHFF...
# 9999  ZHNUHDYFZUAESO-UHFFFAOYSA-NBZYUMXXOAYSFOW-UHFF...
#
# [10000 rows x 1 columns]

# %%
data_generated = pd.read_csv('../data/generated/moses_canonical_INCHIES_1.csv')

data_generated = [k.replace("-N","-N ").split(" ")[:-1] for k in data_generated["SMILES"]]
# Out:
# 10000

# %%
for k in range(len(data_generated)):
    for i in range(len(data_generated[k])):
        list_of_possible_smiles = part_0[data_generated[k][i]==part_0["inchi_key"]]["block"]
        print(len(list_of_possible_smiles))
# Out:
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 124
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 121
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 126
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# 127
# ...
