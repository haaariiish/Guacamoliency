# %%
import pandas as pd
from rdkit import Chem
import matplotlib.pyplot as plt
import numpy as np

# %%
moses = pd.read_csv("../data/training_data/moses_canonical.csv")
moses_smiles = moses["SMILES"].to_list()
moses_mol = [Chem.MolFromSmiles(k) for k in moses_smiles]
moses_inchies = [Chem.inchi.MolToInchi(k) for k in moses_mol if k]

# %% [markdown]
# # exploitation des données avec la saliency

# %%
info_saliency_moses = pd.read_csv("../reports/data/moses_canonical_CL/1/pair_coherence_data_threshold0_sample_length13956.csv")
info_saliency_guacamol = pd.read_csv("../reports/data/guacamol_canonical_CL/1/pair_coherence_data_threshold0_sample_length7867.csv")

# %%
info_saliency_moses[info_saliency_moses["token before the pair"]=="("]["token before the pair"]
# Out:
# Series([], Name: token before the pair, dtype: object)

# %%
def cut(s):
    s = s[1:len(s)-1]
    return int(s)

# %%
true_max_position = info_saliency_moses['position of max score in saliency map']
difference = true_max_position - info_saliency_moses["position of first of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="moses canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between true max and first of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()


true_max_position = info_saliency_moses['position of max score in saliency map']
difference = true_max_position - info_saliency_moses["position of second of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="moses canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between true max and second of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()

difference = info_saliency_moses["position of second of a pair"] - info_saliency_moses["position of first of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="moses canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between first and second of a pair - token : ( )')
ax.legend()
ax.grid()   
ax.plot()
# Out:
# []

# %%
true_max_position = info_saliency_guacamol['position of max score in saliency map']
difference = true_max_position - info_saliency_guacamol["position of first of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="guacamol canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between true max and first of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()

true_max_position = info_saliency_guacamol['position of max score in saliency map']
difference = true_max_position - info_saliency_guacamol["position of second of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="guacamol canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between true max and second of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()

difference = info_saliency_guacamol["position of second of a pair"] - info_saliency_guacamol["position of first of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="guacamol canonical")
ax.set_ylabel('occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between first and second of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()
# Out:
# []

# %%
info_saliency_moses = pd.read_csv("../reports/data/moses_canonical_CL/1/pair_coherence_data_threshold1_sample_length13956.csv")


info_saliency_guacamol = pd.read_csv("../reports/data/guacamol_canonical_CL/1/pair_coherence_data_threshold1_sample_length7867.csv")

# %%
info_saliency_moses
# Out:
#        Unnamed: 0  position of first of a pair  position of second of a pair  \
# 0               0                           10                            12
# 1               1                            3                            16
# 2               2                           18                            21
# 3               3                           25                            27
# 4               4                           28                            30
# ...           ...                          ...                           ...
# 49683       49683                           29                            40
# 49684       49684                            6                             8
# 49685       49685                           13                            16
# 49686       49686                           22                            36
# 49687       49687                           11                            40
#
#        score of first of a pair token before the pair  \
# 0                  4.138915e-21                     c
# 1                  1.866335e-10                     C
# 2                  3.169055e-02                     C
# 3                  9.305601e-17                     C
# 4                  7.033829e-09                     )
# ...                         ...                   ...
# 49683              6.595067e-04                     c
# 49684              5.357111e-02                     c
# 49685              5.394749e-04                     C
# 49686              1.803544e-04                     C
# 49687              2.682278e-04                     c
#
#        score of the token before the pair  \
# 0                            2.346323e-12
# 1                            1.445660e-12
# 2                            8.755036e-04
# 3                            6.925031e-15
# 4                            2.548123e-07
# ...                                   ...
# 49683                        1.283262e-04
# 49684                        6.287678e-02
# 49685                        1.468033e-09
# 49686                        2.308563e-06
# 49687                        4.645093e-04
#
#        position of max score in saliency map  max score in saliency map  \
# 0                                          9               2.346323e-12
# 1                                          4               1.000000e+00
# 2                                         18               3.169055e-02
# 3                                         24               6.925031e-15
# 4                                          4               5.141577e-01
# ...                                      ...                        ...
# 49683                                     31               8.735170e-03
# 49684                                      3               4.269800e-01
# 49685                                     13               5.394749e-04
# 49686                                     34               1.662516e-01
# 49687                                      1               4.434958e-02
#
#       max score token  sum of score between pair  which smile
# 0                   c               0.000000e+00            0
# 1                   S               1.000000e+00            0
# 2                   (               1.248888e-03            0
# 3                   C               0.000000e+00            0
# 4                   S               0.000000e+00            0
# ...               ...                        ...          ...
# 49683               (               1.973130e-02        13954
# 49684               n               0.000000e+00        13955
# 49685               (               6.797177e-07        13955
# 49686               4               1.776886e-01        13955
# 49687               C               2.970405e-02        13955
#
# [49688 rows x 11 columns]

# %%
info_saliency_moses["sum of score between pair"][info_saliency_moses["sum of score between pair"]==1]
# Out:
# 1        1.0
# 189      1.0
# 224      1.0
# 269      1.0
# 289      1.0
#         ...
# 49284    1.0
# 49297    1.0
# 49356    1.0
# 49512    1.0
# 49648    1.0
# Name: sum of score between pair, Length: 420, dtype: float64

# %%
true_max_position = info_saliency_moses['position of max score in saliency map']
difference = true_max_position - info_saliency_moses["position of first of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="moses canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between true max and first of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()



true_max_position = info_saliency_moses['position of max score in saliency map']
difference = true_max_position - info_saliency_moses["position of second of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="moses canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between true max and second of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()

difference = info_saliency_moses["position of second of a pair"] - info_saliency_moses["position of first of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="moses canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between first and second of a pair - token : ( )')
ax.legend()    
ax.grid()
ax.plot()
# Out:
# []

# %%
true_max_position = info_saliency_guacamol['position of max score in saliency map']
difference = true_max_position - info_saliency_guacamol["position of first of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="guacamol canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between true max and first of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()

true_max_position = info_saliency_guacamol['position of max score in saliency map']
difference = true_max_position - info_saliency_guacamol["position of second of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="guacamol canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between true max and second of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()

difference = info_saliency_guacamol["position of second of a pair"] - info_saliency_guacamol["position of first of a pair"]
difference = difference.to_list()
counting = dict()
for k in difference:
    if k in counting.keys():
        counting[k] +=1
    else :
        counting[k] =1

fig, ax = plt.subplots()
ax.bar(counting.keys(),counting.values(), alpha=0.6, label="guacamol canonical")
ax.set_ylabel('Occurences')
ax.set_xlabel('distance (by token)')
ax.set_title('distribution of distance between first and second of a pair - token : ( )')
ax.legend()
ax.grid()
ax.plot()
# Out:
# []

# %%
n = 500
scores_precedent = info_saliency_moses["score of the token before the pair"]
scores_first = info_saliency_moses["score of first of a pair"]

# %%
# Compute bins for both datasets
max1 = max(scores_precedent)
min1 = min(scores_precedent)
max2 = max(scores_first)
min2 = min(scores_first)

_min = min(min1, min2)
_max = max(max1,max2)

if _max >0.01:
    _max = 0.01

bin_width = (_max - _min) / n
x_bins = [_min + k * bin_width for k in range(n+1)]

# Create the plot
fig, ax = plt.subplots()

# Plot histograms
ax.hist(scores_precedent, bins=x_bins, alpha=0.6, label='score of the token before (',density=True)
ax.hist(scores_first, bins=x_bins, alpha=0.6, label='score of the first of a pair',density=True)
ax.grid()
ax.set_ylim((0,500))
ax.legend()

# %%
scores_first_whenmax = info_saliency_guacamol[info_saliency_guacamol['position of max score in saliency map']- info_saliency_guacamol["position of first of a pair"] ==0]["score of first of a pair"]
scores_precedent_whenmax = info_saliency_guacamol[info_saliency_guacamol['position of max score in saliency map']- info_saliency_guacamol["position of first of a pair"] ==0]["score of the token before the pair"]

_max = max(max(scores_first_whenmax),max(scores_precedent_whenmax))
_min = min(min(scores_first_whenmax),min(scores_precedent_whenmax))
fig, ax = plt.subplots()
bin_width = (_max - _min) / n
x_bins = [_min + k * bin_width for k in range(n+1)]
ax.hist(scores_first_whenmax, bins=x_bins, alpha=0.6, label='score of the first of a pair',density=True)
ax.hist(scores_precedent_whenmax, bins=x_bins, alpha=0.6, label='score of the token before (',density=True)
ax.grid()
ax.set_ylim((0,10))
ax.legend()
